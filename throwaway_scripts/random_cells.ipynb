# %%
import numpy as np

lambda_rate = 0.5

np.random.exponential(1/lambda_rate)
# Out:
# Running cells with '.venv (Python 3.12.7)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/user/repos/SentineLLM/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
